# %%
import pandas as pd
import numpy as np 

print (pd.__version__)
print (np.__version__)
# Out:
# 2.2.3
# 2.1.3

# %%
n_rows = 10 
n_cols = 1
cols = ('usia',)

df = pd.DataFrame(np.random.randint(1, 99, size=(n_rows, n_cols)),
                  columns=cols)
df
# Out:
#    usia
# 0    24
# 1    43
# 2    64
# 3    45
# 4    34
# 5    49
# 6    20
# 7    90
# 8    27
# 9    52

# %%
df['kelompok_usia'] = pd.cut(df['usia'],
                             bins=[0, 18, 65, 99],
                             labels=['anak', 'dewasa', 'manula'])

df
# Out:
#    usia kelompok_usia
# 0    24        dewasa
# 1    43        dewasa
# 2    64        dewasa
# 3    45        dewasa
# 4    34        dewasa
# 5    49        dewasa
# 6    20        dewasa
# 7    90        manula
# 8    27        dewasa
# 9    52        dewasa

# %%
import pandas as pd
import numpy as np 

print (pd.__version__)
print (np.__version__)
# Out:
# 2.2.3
# 2.1.3

# %%
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                  columns=cols)

df.head()
# Out:
#     A   B   C   D   E
# 0  17  17   1   6   5
# 1   8   7   1  18   6
# 2   2   6  15   8   1
# 3   8   3   4   6  14
# 4  17   1   6  18   3

# %%
df1 = df.copy(deep=True)
df1 = df1.drop([1, 4])
df1
# Out:
#     A   B   C   D   E
# 0  17  17   1   6   5
# 2   2   6  15   8   1
# 3   8   3   4   6  14
# 5  18   5  17   3   7
# 6  18  16  18  13  12
# 7  12   5   7  11   3
# 8  13  16   8  17  19
# 9  18   1  16   4  15

# %%
df2 = df.copy(deep=True)
df2 = df2.drop([0, 3])
df2
# Out:
#     A   B   C   D   E
# 1   8   7   1  18   6
# 2   2   6  15   8   1
# 4  17   1   6  18   3
# 5  18   5  17   3   7
# 6  18  16  18  13  12
# 7  12   5   7  11   3
# 8  13  16   8  17  19
# 9  18   1  16   4  15

# %%
df_inner = pd.merge(df1, df2, how='inner')
df_inner
# Out:
#     A   B   C   D   E
# 0   2   6  15   8   1
# 1  18   5  17   3   7
# 2  18  16  18  13  12
# 3  12   5   7  11   3
# 4  13  16   8  17  19
# 5  18   1  16   4  15

# %%
df_outer = pd.merge(df1, df2, how='outer')
df_outer
# Out:
#     A   B   C   D   E
# 0   2   6  15   8   1
# 1   8   3   4   6  14
# 2   8   7   1  18   6
# 3  12   5   7  11   3
# 4  13  16   8  17  19
# 5  17   1   6  18   3
# 6  17  17   1   6   5
# 7  18   1  16   4  15
# 8  18   5  17   3   7
# 9  18  16  18  13  12

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.3

# %%
data = {'nama':['Didi Kempot', 'Glenn Fredly', 'Mbah Surip'],
        'tempat_kelahiran':['Surakarta, Jawa Tengah', 'Jakarta, DKI Jakarta', 'Mojoker']}
df = pd.DataFrame(data)
df
# Out:
#            nama        tempat_kelahiran
# 0   Didi Kempot  Surakarta, Jawa Tengah
# 1  Glenn Fredly    Jakarta, DKI Jakarta
# 2    Mbah Surip                 Mojoker

# %%
df[['nama_depan', 'nama_belakang']] = df['nama'].str.split(' ', expand=True) 
df
# Out:
#            nama        tempat_kelahiran nama_depan nama_belakang
# 0   Didi Kempot  Surakarta, Jawa Tengah       Didi        Kempot
# 1  Glenn Fredly    Jakarta, DKI Jakarta      Glenn        Fredly
# 2    Mbah Surip                 Mojoker       Mbah         Surip

# %%
df[['kota', 'provinsi']] = df['tempat_kelahiran'].str.split(',', expand=True) 
df
# Out:
#            nama        tempat_kelahiran nama_depan nama_belakang       kota  \
# 0   Didi Kempot  Surakarta, Jawa Tengah       Didi        Kempot  Surakarta
# 1  Glenn Fredly    Jakarta, DKI Jakarta      Glenn        Fredly    Jakarta
# 2    Mbah Surip                 Mojoker       Mbah         Surip    Mojoker
#
#        provinsi
# 0   Jawa Tengah
# 1   DKI Jakarta
# 2          None

# %%
import pandas as pd

print (pd.__version__)
# Out:
# 2.2.3

# %%
df = pd.read_csv('./data/titanicfull.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df = pd.read_csv('./data/titanicfull.csv')
#       2 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# # Assistant
# This error occurs because Python cannot find the file at the specified path './data/titanicfull.csv'. The file either doesn't exist or the path is incorrect.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # User
# yes

# %%
# Assistant
# Option 1: Use the correct path to your file
# Make sure the path points to where your CSV file is actually located
df = pd.read_csv('correct/path/to/titanicfull.csv')
df.head()

# Option 2: If you don't have the file locally, you can download it from a URL
# For example, using the Titanic dataset from seaborn:
import pandas as pd
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 4
#       1 # Assistant
#       2 # Option 1: Use the correct path to your file
#       3 # Make sure the path points to where your CSV file is actually located
# ----> 4 df = pd.read_csv('correct/path/to/titanicfull.csv')
#       5 df.head()
#       7 # Option 2: If you don't have the file locally, you can download it from a URL
#       8 # For example, using the Titanic dataset from seaborn:
#
# ...
